# %% [markdown]
# <h3>Python List</h3>

# %%
# Creating List

list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]

print(list1)
# Out:
# ['Rahul', 'Amit', 'Raunak', 'Shivam', 'Shalon', 'Gaurav']

# %%
# Positive Indexing

# Always Remember that indexing will starts from 0.

list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]

print(list1[0])
print(list1[1])
print(list1[2])
print(list1[3])
print(list1[4])
print(list1[5])
# Out:
# Rahul
# Amit
# Raunak
# Shivam
# Shalon
# Gaurav

# %%
# Negative Indexing

# Negative indexing means beginning from the end, -1 refers to the last item, -2 refers to the second last item etc.

list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]

print(list1[-1])
print(list1[-2])
print(list1[-3])
print(list1[-4])
print(list1[-5])
print(list1[-6])
# Out:
# Gaurav
# Shalon
# Shivam
# Raunak
# Amit
# Rahul

# %%
# Range of Indexes

# You can specify a range of indexes by specifying where to start and where to end the range.

# When specifying a range, the return value will be a new list with the specified items.

# Always remember end range = end range - 1

list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]

print(list1[2:5])
# Out:
# ['Raunak', 'Shivam', 'Shalon']

# %%
# All The Elements From 0 to 3 
list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]

print(list1[:4])
# Out:
# ['Rahul', 'Amit', 'Raunak', 'Shivam']

# %%
# All The Elements Starting From 1 to all 
list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]

print(list1[1:])
# Out:
# ['Amit', 'Raunak', 'Shivam', 'Shalon', 'Gaurav']

# %%
# Changing Value in a list at a particular index
list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]

list1[1] = "Tarun"
print(list1)
# Out:
# ['Rahul', 'Tarun', 'Raunak', 'Shivam', 'Shalon', 'Gaurav']

# %%
# Loop Through a list using For loop

list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]

for i in list1:
  print(i)
# Out:
# Rahul
# Amit
# Raunak
# Shivam
# Shalon
# Gaurav

# %%
# Check if name exists is list

list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]

if "Pulkit" in list1:
  print("Yes Name Exists")

else: 
  print("Name Does not exists")
# Out:
# Name Does not exists

# %%
# Checking the Length of a List by using len()

print(len(list1))
# Out:
# 6

# %% [markdown]
# <h1>Built In Functions </h1>

# %%
# 1) append()    i.e add a new value in a list

list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]
list1.append("Vaibhav")
print(list1)
# Out:
# ['Rahul', 'Amit', 'Raunak', 'Shivam', 'Shalon', 'Gaurav', 'Vaibhav']

# %%
# 2) insert()  i.e add a new value in a list at a particular index 

list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]
list1.insert(2,"Pulkit")
print(list1)
# Out:
# ['Rahul', 'Amit', 'Pulkit', 'Raunak', 'Shivam', 'Shalon', 'Gaurav']

# %%
# 3) remove()  i.e remove a particular value by its name

list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]
list1.remove("Raunak")
print(list1)
# Out:
# ['Rahul', 'Amit', 'Shivam', 'Shalon', 'Gaurav']

# %%
# 4) pop()   i.e it removes element present at a last position

list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]
list1.pop()
print(list1)
# Out:
# ['Rahul', 'Amit', 'Raunak', 'Shivam', 'Shalon']

# %%
# 5) del()   i.e removes the element at a specified index  and it also use to delete a whole list

list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]
del(list1[2])
print(list1)

list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]
del(list1)
print(list1)
# Out:
# ['Rahul', 'Amit', 'Shivam', 'Shalon', 'Gaurav']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-b638dda36081> in <module>()
#       7 list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]
#       8 del(list1)
# ----> 9 print(list1)
#
# NameError: name 'list1' is not defined

# %%
# 6) clear()   i.e it removes all the elements present in a list and list becomes empty

list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]
list1.clear()
print(list1)
# Out:
# []

# %%
# 7) copy()   i.e make a copy of a list

list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]
list2 = list1.copy()
print(list2)
# Out:
# ['Rahul', 'Amit', 'Raunak', 'Shivam', 'Shalon', 'Gaurav']

# %%
# 8) extend()   i.e to add list1 at the end of list2

list1 = ["x", "y" , "z"]
list2 = [1, 2, 3]

list2.extend(list1)
print(list2)
# Out:
# [1, 2, 3, 'x', 'y', 'z']

# %%
# 9) reverse()   i.e reverse the list elements

list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]
list1.reverse()
print(list1)
# Out:
# ['Gaurav', 'Shalon', 'Shivam', 'Raunak', 'Amit', 'Rahul']

# %%
# 10) sort()    i.e sort the list alphabetically

list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]
list1.sort(reverse=False)     # Here reverse is used to put the elements in descending order after sorting i.e Z-A
print(list1)
# Out:
# ['Amit', 'Gaurav', 'Rahul', 'Raunak', 'Shalon', 'Shivam']

# %%
# Join two list by using (+) operator

list1 = ["Rahul","Amit","Raunak","Shivam","Shalon","Gaurav"]
list2 = [1,2,3,4,5,6]

list3 = list1 + list2
print(list3)
# Out:
# ['Rahul', 'Amit', 'Raunak', 'Shivam', 'Shalon', 'Gaurav', 1, 2, 3, 4, 5, 6]

# %%
# We can also create a list by using the list constructor.
list1 = list(("Apple", "Mango", "Cherry"))
print(list1)

# Check its type
print(type(list1))
# Out:
# ['Apple', 'Mango', 'Cherry']
# <class 'list'>
