# %%
# Create a Tuple

tuple1 = ("Rohit", "Ankit", "Rohan")
print(tuple1)
# Out:
# ('Rohit', 'Ankit', 'Rohan')

# %%
# Accessing Tuple Items

tuple1 = ("Rohit", "Ankit", "Rohan")
print(tuple1[0])
# Out:
# Rohit

# %%
# Negative Indexing

# Negative indexing means beginning from the end, -1 refers to the last item, -2 refers to the second last item etc.

tuple1 = ("Rohit", "Ankit", "Rohan")
print(tuple1[-1])


#

print(tuple1[-2])
print(tuple1[-3])
# Out:
# Rohan
# Ankit
# Rohit

# %%
# Range of Indexes

# You can specify a range of indexes by specifying where to start and where to end the range.

# When specifying a range, the return value will be a new tuple with the specified items.

a = ("Rohit", "Ankit", "Rohan","Shyam","Siddhant")
print(a[2:5])

# Negative Range

print(a[-4:-1])
# Out:
# ('Rohan', 'Shyam', 'Siddhant')
# ('Ankit', 'Rohan', 'Shyam')

# %%
# Change Tuple Values

# Once a tuple is created, you cannot change its values. Tuples are unchangeable, or immutable.

# But there is a workaround. You can convert the tuple into a list, change the list, and convert the list back into a tuple.

a = ("Rohit", "Ankit", "Rohan","Shyam","Siddhant")
b = list(a)
print(b)

b.append("Pulkit")
print(b)

a = tuple(b)
print(a)
print(type(a))
# Out:
# ['Rohit', 'Ankit', 'Rohan', 'Shyam', 'Siddhant']
# ['Rohit', 'Ankit', 'Rohan', 'Shyam', 'Siddhant', 'Pulkit']
# ('Rohit', 'Ankit', 'Rohan', 'Shyam', 'Siddhant', 'Pulkit')
# <class 'tuple'>

# %%
# Loop Through A Tuple

a = ("Rohit", "Ankit", "Rohan","Shyam","Siddhant")
for i in a:
  print(i)
# Out:
# Rohit
# Ankit
# Rohan
# Shyam
# Siddhant

# %%
# Check whether name exists in tuple

a = ("Rohit", "Ankit", "Rohan","Shyam","Siddhant")
if "Ankit" in a:
  print("Yes it Exists")
else:
  print("No")
# Out:
# Yes it Exists

# %%
# Length of a Tuple

a = ("Rohit", "Ankit", "Rohan","Shyam","Siddhant")
print(len(a))
# Out:
# 5

# %% [markdown]
# <h3>Important</h3>

# %%
x = ("Pulkit")
print(type(x))

# As u see its not a tuple its a string with only one element
# Out:
# <class 'str'>

# %%
y = ("Pulkit",)
print(type(y))

# See now its a tuple
# Out:
# <class 'tuple'>

# %%
# Joining Two Tuples

m = ("Pulkit",)
n = ("Tarun",)

o = m + n
print(o)
print(type(o))
# Out:
# ('Pulkit', 'Tarun')
# <class 'tuple'>

# %%
# count()   # It Returns number of times value appears in a tuple

a = ("Rohit", "Ankit", "Rohan","Shyam","Siddhant")

g = a.count("Pulkit")
f = a.count("Rohan")

print(g)
print(f)
# Out:
# 0
# 1

# %%
# index()    # Search for the first occurrence of the value 4, and return its position:

t = (0,1,2,4,3,5,4,6,4,7,2,1,8)

t1 = t.index(4)
print(t1)
# Out:
# 3

# %%
# max()   # It returns the elements from the tuple with maximum value.   # In Strings it compares through ASCII Codes.


tuple1, tuple2 = ("PQR", 'abc', 'shyam', 'ram'), (956, 1000, 1200)
print("Max value element : ", max(tuple1))
print("Max value element : ", max(tuple2))
# Out:
# Max value element :  shyam
# Max value element :  1200

# %%
# min()   # It returns the elements from the tuple with minimum value.   # In Strings it compares through ASCII Codes.


tuple1, tuple2 = ("PQR", 'abc', 'shyam', 'ram'), (956, 1000, 1200)
print("Min value element : ", min(tuple1))
print("Min value element : ", min(tuple2))
# Out:
# Min value element :  PQR
# Min value element :  956
